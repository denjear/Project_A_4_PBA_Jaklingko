# %% [markdown]
# ## Article Scraping

# %%
# !pip install feedparser pandas dateparser --quiet

import feedparser
import pandas as pd
import hashlib
from datetime import datetime
from urllib.parse import quote, urlparse, parse_qs
import dateparser
import json

def get_real_url(possible_redirect_link):
    """
    Google News RSS sering memberikan link redirect seperti:
    https://news.google.com/articles/CAIi...&url=https://actual.site/...
    Fungsi ini mencoba mengekstrak parameter `url=` jika ada; kalau tidak, return link as-is.
    """
    try:
        parsed = urlparse(possible_redirect_link)
        qs = parse_qs(parsed.query)
        if "url" in qs and qs["url"]:
            return qs["url"][0]
    except Exception:
        pass
    return possible_redirect_link

def normalize_date(date_str):

    if not date_str:
        return None
    try:
        dt = dateparser.parse(str(date_str), languages=["id", "en"])
        if dt:
            return dt.isoformat()
    except Exception:
        pass
    # fallback: return original trimmed
    return str(date_str).strip()

def scrape_google_news_rss(query, max_items=None):
    """
    query: string, e.g. 'Jaklingko OR "Jak Lingko"'
    max_items: optional int to limit number of entries processed
    returns: list of dicts
    """
    encoded_q = quote(query)
    rss_url = f"https://news.google.com/rss/search?q={encoded_q}&hl=id&gl=ID&ceid=ID:id"
    feed = feedparser.parse(rss_url)

    out = []
    entries = feed.entries or []
    if max_items:
        entries = entries[:max_items]

    for e in entries:
        title = e.get("title")
        raw_link = e.get("link")
        link = get_real_url(raw_link) if raw_link else None

        # feedparser sometimes stores source as object-like; handle safely
        source = None
        src = e.get("source")
        if isinstance(src, dict):
            source = src.get("title")
        elif hasattr(src, "title"):
            try:
                source = src.title
            except Exception:
                source = str(src)
        else:
            # fallback: try to parse from entry.author or other fields
            source = e.get("author") or e.get("publisher") or None

        # date fields may be published/updated/updated_parsed etc.
        published_raw = e.get("published") or e.get("updated") or e.get("published_parsed") or None
        published = normalize_date(published_raw)

        # summary/description if available (RSS often includes short snippet)
        summary = e.get("summary") or e.get("description") or ""

        uid = hashlib.sha256((link or title or "").encode("utf-8")).hexdigest()[:16]

        out.append({
            "id": uid,
            "query_used": query,
            "title": title,
            "url": link,
            "source": source,
            "published": published,
            "summary": summary
        })

    return out

if __name__ == "__main__":
    # --- CONFIGURE QUERY HERE ---
    # You can change query to other variants, e.g. 'Jaklingko OR "Jak Lingko" OR "tarif integrasi"'
    query = 'Jaklingko OR "Jak Lingko"'
    max_items = None   # set integer to limit results, e.g. 50

    print("Scraping Google News RSS for query:", query)
    data = scrape_google_news_rss(query, max_items=max_items)
    print(f"Found {len(data)} entries from RSS")

    # convert to DataFrame
    df = pd.DataFrame(data)

    # deduplicate by URL (keep first)
    if not df.empty:
        df = df.drop_duplicates(subset=["url"], keep="first")

    # filenames
    date_tag = datetime.now().strftime("%Y%m%d")
    csv_name = f"jaklingko_news_{date_tag}.csv"
    jsonl_name = f"jaklingko_news_{date_tag}.jsonl"

    # Save CSV
    df.to_csv(csv_name, index=False, encoding="utf-8-sig")
    print("Saved CSV:", csv_name)

    # Save JSONL
    with open(jsonl_name, "w", encoding="utf-8") as jf:
        for row in data:
            jf.write(json.dumps(row, ensure_ascii=False) + "\n")
    print("Saved JSONL:", jsonl_name)

    # Preview
    if df.empty:
        print("⚠️ DataFrame kosong — tidak ada artikel ter-ekstrak dari RSS.")
    else:
        print(df.head(10).to_string(index=False))

    # note for Colab: to download files, use:
    # from google.colab import files
    # files.download(csv_name)
# Out:
# Scraping Google News RSS for query: Jaklingko OR "Jak Lingko"
# Found 100 entries from RSS
# Saved CSV: jaklingko_news_20250930.csv
# Saved JSONL: jaklingko_news_20250930.jsonl
#               id                query_used                                                                                                                        title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           url                    source                 published                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           summary
# f2732156d88f1ab4 Jaklingko OR "Jak Lingko" Naik Angkot Jaklingko Gratis Itu Menyenangkan, Kecuali Kalau Sopirnya Nyetir Kayak Lagi Balapan di Sirkuit Sentul - Mojok.co                                                                                                                                         https://news.google.?oc=5                  Mojok.co 2025-09-04T07:00:00+00:00                                                                                                            <a href="https://news.google.?oc=5" target="_blank">Naik Angkot Jaklingko Gratis Itu Menyenangkan, Kecuali Kalau Sopirnya Nyetir Kayak Lagi Balapan di Sirkuit Sentul</a>&nbsp;&nbsp;<font color="#6f6f6f">Mojok.co</font>
# a4069a959834aee6 Jaklingko OR "Jak Lingko"                             Rute Jaklingko Jakarta Timur 2025 beserta Jam Operasional dan Tarifnya - kumparan.com - Kumparan  https://news.google....?oc=5                  Kumparan 2025-09-28T05:54:00+00:00 <a href="https://news.google....?oc=5" target="_blank">Rute Jaklingko Jakarta Timur 2025 beserta Jam Operasional dan Tarifnya - kumparan.com</a>&nbsp;&nbsp;<font color="#6f6f6f">Kumparan</font>
# 47400a6eaa10603b Jaklingko OR "Jak Lingko"                                Dilema Hadirnya Jaklingko, Sopir Angkot Regular Mengeluh Sulit Dapat Uang - Wartakotalive.com                                                                                                                                                                                                                                                                  https://news.google.?oc=5         Wartakotalive.com 2025-09-27T03:27:14+00:00                                                                                                                                                                                                                                                                    <a href="https://news.google.?oc=5" target="_blank">Dilema Hadirnya Jaklingko, Sopir Angkot Regular Mengeluh Sulit Dapat Uang</a>&nbsp;&nbsp;<font color="#6f6f6f">Wartakotalive.com</font>
# 08902358980ad48d Jaklingko OR "Jak Lingko"                                                    Nasib Sopir Jaklingko, Saat Tarikan Gas tak Sekencang Gaji - Republika.id                                                                                                                                                                                                                                                                                                                https://news.google.com/rss/articles/CBMimgFBVV95cUxQcW1yRUw4ZWdxUHpIbHhlN0dtX3c2QlVyN0N1b1Z0bGxZXzlvVFI3aWcxMXF2aWJMNGN2d3M3TENqSm1GYTkwR1Q4UUdVeEVESnpaTi1yZXhwOGVRUG1ZaDR5RXMxdkJnZm9OOGxteXNsdFZJbmR5eklLZmVScF9FOGh0VERtcXlRSlVfNEFlbVY3blVnQWFZQ1B3?oc=5              Republika.id 2025-08-06T07:00:00+00:00                                                                                                                                                                                                                                                                                                                                      <a href="https://news.google.com/rss/articles/CBMimgFBVV95cUxQcW1yRUw4ZWdxUHpIbHhlN0dtX3c2QlVyN0N1b1Z0bGxZXzlvVFI3aWcxMXF2aWJMNGN2d3M3TENqSm1GYTkwR1Q4UUdVeEVESnpaTi1yZXhwOGVRUG1ZaDR5RXMxdkJnZm9OOGxteXNsdFZJbmR5eklLZmVScF9FOGh0VERtcXlRSlVfNEFlbVY3blVnQWFZQ1B3?oc=5" target="_blank">Nasib Sopir Jaklingko, Saat Tarikan Gas tak Sekencang Gaji</a>&nbsp;&nbsp;<font color="#6f6f6f">Republika.id</font>
# d4879e745ffce48a Jaklingko OR "Jak Lingko"                                            Seluruh Layanan TransJakarta dan Jaklingko Dihentikan Sementara - MetroTVNews.com                                                                                                                                                                                                                                                                                             https://news.google.com/rss/articles/CBMiqAFBVV95cUxOMEdpUTdhcWtoakNLbTBuSmZ4Uy1yMEZydDduUU5KRFVhWmVObXhNUGRXNWl0UURPdGVaTGZCZzkwZWJHNjFHTVBBRnh2eExQcWpiT1RNNXVraW5mRkJlY0F5LXM0b2hEMGxjbC1odGY2R1J6a2hTNEIzR2dKSkgtT2I1bmRhdlpiMlp5OGhzQXRRREJGbkg5TmhneEh0dklzbGgweWEteTg?oc=5           MetroTVNews.com 2025-08-30T07:00:00+00:00                                                                                                                                                                                                                                                                                                           <a href="https://news.google.com/rss/articles/CBMiqAFBVV95cUxOMEdpUTdhcWtoakNLbTBuSmZ4Uy1yMEZydDduUU5KRFVhWmVObXhNUGRXNWl0UURPdGVaTGZCZzkwZWJHNjFHTVBBRnh2eExQcWpiT1RNNXVraW5mRkJlY0F5LXM0b2hEMGxjbC1odGY2R1J6a2hTNEIzR2dKSkgtT2I1bmRhdlpiMlp5OGhzQXRRREJGbkg5TmhneEh0dklzbGgweWEteTg?oc=5" target="_blank">Seluruh Layanan TransJakarta dan Jaklingko Dihentikan Sementara</a>&nbsp;&nbsp;<font color="#6f6f6f">MetroTVNews.com</font>
# c265f20d2ae274f1 Jaklingko OR "Jak Lingko"                                   Naik MRT, KRL, Transjakarta, hingga JakLingko Cuma Rp 80 Saat 17 Agustus 2025 - Kompas.com                                                                                                                                                                                                                                                     https://news.google.?oc=5                Kompas.com 2025-08-01T07:00:00+00:00                                                                                                                                                                                                                                                          <a href="https://news.google.?oc=5" target="_blank">Naik MRT, KRL, Transjakarta, hingga JakLingko Cuma Rp 80 Saat 17 Agustus 2025</a>&nbsp;&nbsp;<font color="#6f6f6f">Kompas.com</font>
# a4af24325d88d1ca Jaklingko OR "Jak Lingko"                    Pemkot Tangerang Dukung Rencana Perpanjangan Rute JakLingko ke Kota Tangerang - Pemerintah Kota Tangerang                                                                                                                                                                                                                                                  https://news.google.?oc=5 Pemerintah Kota Tangerang 2025-04-10T07:00:00+00:00                                                                                                                                                                                                                                        <a href="https://news.google.?oc=5" target="_blank">Pemkot Tangerang Dukung Rencana Perpanjangan Rute JakLingko ke Kota Tangerang</a>&nbsp;&nbsp;<font color="#6f6f6f">Pemerintah Kota Tangerang</font>
# 5841f2c2f959e105 Jaklingko OR "Jak Lingko"                                   Pramono Wanti-wanti Sopir Jaklingko Ugal-ugalan Ditertibkan atau Diberhentikan - detikNews https://news.google....?oc=5                 detikNews 2025-06-18T07:00:00+00:00      <a href="https://news.google....?oc=5" target="_blank">Pramono Wanti-wanti Sopir Jaklingko Ugal-ugalan Ditertibkan atau Diberhentikan</a>&nbsp;&nbsp;<font color="#6f6f6f">detikNews</font>
# abf89aaa47a818e7 Jaklingko OR "Jak Lingko"                                                   Pramono Ingin Mikrotrans JakLingko Beroperasi di Kota Penyangga - Tempo.co                                                                                                                                                                                                                                                                                                     https://news.google.com/rss/articles/CBMiogFBVV95cUxQNWFoNXhPQU1tM3gtSmw2RHpsRlhEcmhuTGc2OG8tOGo2elcwTWFDX2FZQ0ttTWNTWXBnenpYMXpOVUxENUhEU0pBWktHYVNlQUtqV3ZDRkUtVEo4eHhuTUpLUnNNM3pHXzNCODBhN1dKcV9ldFdjZzZPVm1UbnVMTFkzemZhcG1mS2NxWkFOM1pjelBobHVHNlJMZmg5Y21BQkE?oc=5                  Tempo.co 2025-06-12T07:00:00+00:00                                                                                                                                                                                                                                                                                                                          <a href="https://news.google.com/rss/articles/CBMiogFBVV95cUxQNWFoNXhPQU1tM3gtSmw2RHpsRlhEcmhuTGc2OG8tOGo2elcwTWFDX2FZQ0ttTWNTWXBnenpYMXpOVUxENUhEU0pBWktHYVNlQUtqV3ZDRkUtVEo4eHhuTUpLUnNNM3pHXzNCODBhN1dKcV9ldFdjZzZPVm1UbnVMTFkzemZhcG1mS2NxWkFOM1pjelBobHVHNlJMZmg5Y21BQkE?oc=5" target="_blank">Pramono Ingin Mikrotrans JakLingko Beroperasi di Kota Penyangga</a>&nbsp;&nbsp;<font color="#6f6f6f">Tempo.co</font>
# e5ce427ce039a9d7 Jaklingko OR "Jak Lingko"                                     Operasional TransJakarta dan Jaklingko Hampir 100% Normal, Ini Daftar Rutenya - Bola.com                                  https://news.google....?oc=5                  Bola.com 2025-08-31T07:00:00+00:00                                         <a href="https://news.google....?oc=5" target="_blank">Operasional TransJakarta dan Jaklingko Hampir 100% Normal, Ini Daftar Rutenya</a>&nbsp;&nbsp;<font color="#6f6f6f">Bola.com</font>

# %%
# !pip install feedparser pandas dateparser --quiet

import feedparser
import pandas as pd
import hashlib
from datetime import datetime
from urllib.parse import quote, urlparse, parse_qs
import dateparser
import json

def get_real_url(possible_redirect_link):
    """
    Google News RSS sering memberikan link redirect seperti:
    https://news.google.com/articles/CAIi...&url=https://actual.site/...
    Fungsi ini mencoba mengekstrak parameter `url=` jika ada; kalau tidak, return link as-is.
    """
    try:
        parsed = urlparse(possible_redirect_link)
        qs = parse_qs(parsed.query)
        if "url" in qs and qs["url"]:
            return qs["url"][0]
    except Exception:
        pass
    return possible_redirect_link

def normalize_date(date_str):
    if not date_str:
        return None
    try:
        dt = dateparser.parse(str(date_str), languages=["id", "en"])
        if dt:
            return dt.isoformat()
    except Exception:
        pass
    return str(date_str).strip()

def scrape_google_news_rss(query, max_items=None):
    """
    query: string, e.g. 'Jaklingko OR "Jak Lingko"'
    max_items: optional int to limit number of entries processed
    returns: list of dicts
    """
    encoded_q = quote(query)
    rss_url = f"https://news.google.com/rss/search?q={encoded_q}&hl=id&gl=ID&ceid=ID:id"
    feed = feedparser.parse(rss_url)

    out = []
    entries = feed.entries or []
    if max_items:
        entries = entries[:max_items]

    for e in entries:
        title = e.get("title")
        raw_link = e.get("link")
        link = get_real_url(raw_link) if raw_link else None

        # Ambil source
        source = None
        src = e.get("source")
        if isinstance(src, dict):
            source = src.get("title")
        elif hasattr(src, "title"):
            try:
                source = src.title
            except Exception:
                source = str(src)
        else:
            source = e.get("author") or e.get("publisher") or None

        # Ambil tanggal publikasi
        published_raw = e.get("published") or e.get("updated") or e.get("published_parsed") or None
        published = normalize_date(published_raw)

        uid = hashlib.sha256((link or title or "").encode("utf-8")).hexdigest()[:16]

        out.append({
            "id": uid,
            "query_used": query,
            "title": title,
            "url": link,
            "source": source,
            "published": published
        })

    return out

if __name__ == "__main__":
    # --- CONFIGURE QUERY HERE ---
    query = 'Jaklingko OR "Jak Lingko"'
    max_items = None   # set integer kalau mau dibatasi, misal 20

    print("Scraping Google News RSS for query:", query)
    data = scrape_google_news_rss(query, max_items=150)
    print(f"Found {len(data)} entries from RSS")

    df = pd.DataFrame(data)

    if not df.empty:
        # Deduplicate
        df = df.drop_duplicates(subset=["url"], keep="first")

        # Format sesuai tabel target
        df_formatted = pd.DataFrame({
            "No": range(1, len(df) + 1),
            "Title": df["title"],
            "Link": df["url"],
            "Source": df["source"],
            "Date": df["published"],
            "PIC": ""  # kosong dulu
        })

        # Filenames
        date_tag = datetime.now().strftime("%Y%m%d")
        csv_name = f"jaklingko_news_{date_tag}.csv"
        jsonl_name = f"jaklingko_news_{date_tag}.jsonl"

        # Save CSV
        df_formatted.to_csv(csv_name, index=False, encoding="utf-8-sig")
        print("Saved CSV:", csv_name)

        # Save JSONL
        with open(jsonl_name, "w", encoding="utf-8") as jf:
            for _, row in df_formatted.iterrows():
                jf.write(json.dumps(row.to_dict(), ensure_ascii=False) + "\n")
        print("Saved JSONL:", jsonl_name)

        # Preview
        print(df_formatted.head(10).to_string(index=False))
    else:
        print("⚠️ DataFrame kosong — tidak ada artikel ter-ekstrak dari RSS.")
# Out:
# Scraping Google News RSS for query: Jaklingko OR "Jak Lingko"
# Found 100 entries from RSS
# Saved CSV: jaklingko_news_20250930.csv
# Saved JSONL: jaklingko_news_20250930.jsonl
#  No                                                                                                                        Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Link                    Source                      Date PIC
#   1 Naik Angkot Jaklingko Gratis Itu Menyenangkan, Kecuali Kalau Sopirnya Nyetir Kayak Lagi Balapan di Sirkuit Sentul - Mojok.co                                                                                                                                         https://news.google.?oc=5                  Mojok.co 2025-09-04T07:00:00+00:00
#   2                             Rute Jaklingko Jakarta Timur 2025 beserta Jam Operasional dan Tarifnya - kumparan.com - Kumparan  https://news.google....?oc=5                  Kumparan 2025-09-28T05:54:00+00:00
#   3                                Dilema Hadirnya Jaklingko, Sopir Angkot Regular Mengeluh Sulit Dapat Uang - Wartakotalive.com                                                                                                                                                                                                                                                                  https://news.google.?oc=5         Wartakotalive.com 2025-09-27T03:27:14+00:00
#   4                                                    Nasib Sopir Jaklingko, Saat Tarikan Gas tak Sekencang Gaji - Republika.id                                                                                                                                                                                                                                                                                                                https://news.google.com/rss/articles/CBMimgFBVV95cUxQcW1yRUw4ZWdxUHpIbHhlN0dtX3c2QlVyN0N1b1Z0bGxZXzlvVFI3aWcxMXF2aWJMNGN2d3M3TENqSm1GYTkwR1Q4UUdVeEVESnpaTi1yZXhwOGVRUG1ZaDR5RXMxdkJnZm9OOGxteXNsdFZJbmR5eklLZmVScF9FOGh0VERtcXlRSlVfNEFlbVY3blVnQWFZQ1B3?oc=5              Republika.id 2025-08-06T07:00:00+00:00
#   5                                            Seluruh Layanan TransJakarta dan Jaklingko Dihentikan Sementara - MetroTVNews.com                                                                                                                                                                                                                                                                                             https://news.google.com/rss/articles/CBMiqAFBVV95cUxOMEdpUTdhcWtoakNLbTBuSmZ4Uy1yMEZydDduUU5KRFVhWmVObXhNUGRXNWl0UURPdGVaTGZCZzkwZWJHNjFHTVBBRnh2eExQcWpiT1RNNXVraW5mRkJlY0F5LXM0b2hEMGxjbC1odGY2R1J6a2hTNEIzR2dKSkgtT2I1bmRhdlpiMlp5OGhzQXRRREJGbkg5TmhneEh0dklzbGgweWEteTg?oc=5           MetroTVNews.com 2025-08-30T07:00:00+00:00
#   6                                   Naik MRT, KRL, Transjakarta, hingga JakLingko Cuma Rp 80 Saat 17 Agustus 2025 - Kompas.com                                                                                                                                                                                                                                                     https://news.google.?oc=5                Kompas.com 2025-08-01T07:00:00+00:00
#   7                 program jak-lingko transjakarta dalam upaya perbaikan transportasi publik di pinang ranti - researchgate.net                                                                                                                                                             https://news.google.?oc=5          researchgate.net 2025-08-06T07:00:00+00:00
#   8                    Pemkot Tangerang Dukung Rencana Perpanjangan Rute JakLingko ke Kota Tangerang - Pemerintah Kota Tangerang                                                                                                                                                                                                                                                  https://news.google.?oc=5 Pemerintah Kota Tangerang 2025-04-10T07:00:00+00:00
#   9                                   Pramono Wanti-wanti Sopir Jaklingko Ugal-ugalan Ditertibkan atau Diberhentikan - detikNews https://news.google....?oc=5                 detikNews 2025-06-18T07:00:00+00:00
#  10                                                   Pramono Ingin Mikrotrans JakLingko Beroperasi di Kota Penyangga - Tempo.co                                                                                                                                                                                                                                                                                                     https://news.google.com/rss/articles/CBMiogFBVV95cUxQNWFoNXhPQU1tM3gtSmw2RHpsRlhEcmhuTGc2OG8tOGo2elcwTWFDX2FZQ0ttTWNTWXBnenpYMXpOVUxENUhEU0pBWktHYVNlQUtqV3ZDRkUtVEo4eHhuTUpLUnNNM3pHXzNCODBhN1dKcV9ldFdjZzZPVm1UbnVMTFkzemZhcG1mS2NxWkFOM1pjelBobHVHNlJMZmg5Y21BQkE?oc=5                  Tempo.co 2025-06-12T07:00:00+00:00

# %%
# !pip install feedparser pandas dateparser --quiet

import feedparser
import pandas as pd
import hashlib
from datetime import datetime
from urllib.parse import quote, urlparse, parse_qs
import dateparser
import json

def get_real_url(possible_redirect_link):
    try:
        parsed = urlparse(possible_redirect_link)
        qs = parse_qs(parsed.query)
        if "url" in qs and qs["url"]:
            return qs["url"][0]
    except Exception:
        pass
    return possible_redirect_link

def normalize_date(date_str):
    if not date_str:
        return None
    try:
        dt = dateparser.parse(str(date_str), languages=["id", "en"])
        if dt:
            return dt.isoformat()
    except Exception:
        pass
    return str(date_str).strip()

def scrape_google_news_rss(query, max_items=None):
    encoded_q = quote(query)
    rss_url = f"https://news.google.com/rss/search?q={encoded_q}&hl=id&gl=ID&ceid=ID:id"
    feed = feedparser.parse(rss_url)

    out = []
    entries = feed.entries or []
    if max_items:
        entries = entries[:max_items]

    for e in entries:
        title = e.get("title")
        raw_link = e.get("link")
        link = get_real_url(raw_link) if raw_link else None

        source = None
        src = e.get("source")
        if isinstance(src, dict):
            source = src.get("title")
        elif hasattr(src, "title"):
            try:
                source = src.title
            except Exception:
                source = str(src)
        else:
            source = e.get("author") or e.get("publisher") or None

        published_raw = e.get("published") or e.get("updated") or e.get("published_parsed") or None
        published = normalize_date(published_raw)

        summary = e.get("summary") or e.get("description") or ""

        uid = hashlib.sha256((link or title or "").encode("utf-8")).hexdigest()[:16]

        out.append({
            "id": uid,
            "query_used": query,
            "title": title,
            "url": link,
            "source": source,
            "published": published,
            "summary": summary
        })

    return out


if __name__ == "__main__":
    all_data = []

    # Loop setiap bulan di 2023
    for month in range(1, 13):
        start = f"2023-{month:02d}-01"
        if month == 12:
            end = "2023-12-31"
        else:
            end = f"2023-{month+1:02d}-01"

        query = f'Jaklingko after:{start} before:{end}'
        print(f"Scraping bulan {month} 2023...")

        data = scrape_google_news_rss(query, max_items=100)
        all_data.extend(data)

    # Buat DataFrame
    df = pd.DataFrame(all_data)

    # Konversi ke datetime & filter hanya tahun 2023
    df["published"] = pd.to_datetime(df["published"], errors="coerce")
    df_2023 = df[df["published"].dt.year == 2023].drop_duplicates(subset=["url"]).reset_index(drop=True)

    # Save ke CSV
    date_tag = datetime.now().strftime("%Y%m%d")
    csv_name = f"jaklingko_news_2023_{date_tag}.csv"
    df_2023.to_csv(csv_name, index=False, encoding="utf-8-sig")

    print(f"✅ Artikel tahun 2023: {len(df_2023)}")
    print("Saved CSV:", csv_name)
    print(df_2023.head(10).to_string(index=False))
# Out:
# Scraping bulan 1 2023...
# Scraping bulan 2 2023...
# Scraping bulan 3 2023...
# Scraping bulan 4 2023...
# Scraping bulan 5 2023...
# Scraping bulan 6 2023...
# Scraping bulan 7 2023...
# Scraping bulan 8 2023...
# Scraping bulan 9 2023...
# Scraping bulan 10 2023...
# Scraping bulan 11 2023...
# Scraping bulan 12 2023...
# ✅ Artikel tahun 2023: 169
# Saved CSV: jaklingko_news_2023_20250930.csv
#               id                                   query_used                                                                                                                                           title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          url                                                            source                 published                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    summary
# d33f1e6359af80f7 Jaklingko after:2023-01-01 before:2023-02-01 Potensi 'Scaling Up' Jak Lingko sebagai Sistem Transportasi Publik Nasional - Kementerian Pendayagunaan Aparatur Negara dan Reformasi Birokrasi                                                                                                                                                                                                                                            https://news.google.?oc=5 Kementerian Pendayagunaan Aparatur Negara dan Reformasi Birokrasi 2023-01-11 08:00:00+00:00                                                                                                                                                                                      <a href="https://news.google.?oc=5" target="_blank">Potensi 'Scaling Up' Jak Lingko sebagai Sistem Transportasi Publik Nasional</a>&nbsp;&nbsp;<font color="#6f6f6f">Kementerian Pendayagunaan Aparatur Negara dan Reformasi Birokrasi</font>
# 6c487af3112fb6b6 Jaklingko after:2023-01-01 before:2023-02-01                                                                         MRT Jakarta Sediakan Mesin Isi Ulang Uang Elektronik Bank - MRT Jakarta                                                                                                                                                                                                                                                                        https://news.google.com/rss/articles/CBMinwFBVV95cUxQQ1htZmRTXzBpZWxwNFdudDhuem5fQlp5dldiX2RMTDZyRGtFVEh5dXFNMVF0WFlyNmpvejJ3MWFHNXBZRkl6U0lVcm1yb0g5cTNQaHBGT2lOeEN5MmRuWmszdEQ5Y3J3elV6SjE3cXlGQk02WGNKbkh0TlVfenBXblNGZzdHc1VLX2Nkck9JcjVCWGdieXdkRXFwU3Z5eHc?oc=5                                                       MRT Jakarta 2023-01-19 08:32:22+00:00                                                                                                                                                                                                                                                                                          <a href="https://news.google.com/rss/articles/CBMinwFBVV95cUxQQ1htZmRTXzBpZWxwNFdudDhuem5fQlp5dldiX2RMTDZyRGtFVEh5dXFNMVF0WFlyNmpvejJ3MWFHNXBZRkl6U0lVcm1yb0g5cTNQaHBGT2lOeEN5MmRuWmszdEQ5Y3J3elV6SjE3cXlGQk02WGNKbkh0TlVfenBXblNGZzdHc1VLX2Nkck9JcjVCWGdieXdkRXFwU3Z5eHc?oc=5" target="_blank">MRT Jakarta Sediakan Mesin Isi Ulang Uang Elektronik Bank</a>&nbsp;&nbsp;<font color="#6f6f6f">MRT Jakarta</font>
# 89e6e83c5d44882a Jaklingko after:2023-01-01 before:2023-02-01                                                          Driver Gojek Tabrak Angkot Jaklingko hingga Penyok di Lenteng Agung. - Patra Indonesia                                                                                                                                                                                                                                                                             https://news.google.com/rss/articles/CBMimwFBVV95cUxNQmtwM3dtWmJPVlJUTExneFVVTk42ckY1T2YzVWZsZlJ2aE44dFA2QVBwbUlqY0tic0ZGY2RaRUk4UTJQTnByWThFTjZhYXZjNU1JekQtdDh6ZG9ORUtkMXQybGRUWnh1YTIwYkNIczdGU3dHSkcyWndOcXNiMWI3QUlDLWIwd3FEQ3dSZEp6OGh5MW9ISzROYkxyUQ?oc=5                                                   Patra Indonesia 2023-01-18 08:00:00+00:00                                                                                                                                                                                                                                                                                <a href="https://news.google.com/rss/articles/CBMimwFBVV95cUxNQmtwM3dtWmJPVlJUTExneFVVTk42ckY1T2YzVWZsZlJ2aE44dFA2QVBwbUlqY0tic0ZGY2RaRUk4UTJQTnByWThFTjZhYXZjNU1JekQtdDh6ZG9ORUtkMXQybGRUWnh1YTIwYkNIczdGU3dHSkcyWndOcXNiMWI3QUlDLWIwd3FEQ3dSZEp6OGh5MW9ISzROYkxyUQ?oc=5" target="_blank">Driver Gojek Tabrak Angkot Jaklingko hingga Penyok di Lenteng Agung.</a>&nbsp;&nbsp;<font color="#6f6f6f">Patra Indonesia</font>
# 27f68483de2887da Jaklingko after:2023-01-01 before:2023-02-01                                               JakLingko Dinobatkan sebagai Finalis Transport Ticketing Global Awards 2023 di Inggris - Tempo.co                                                                                                                                                                                                                                 https://news.google.?oc=5                                                          Tempo.co 2023-01-31 08:00:00+00:00                                                                                                                                                                                                                         <a href="https://news.google.?oc=5" target="_blank">JakLingko Dinobatkan sebagai Finalis Transport Ticketing Global Awards 2023 di Inggris</a>&nbsp;&nbsp;<font color="#6f6f6f">Tempo.co</font>
# bdfde1024c0c9c8d Jaklingko after:2023-01-01 before:2023-02-01                                                                                          4 Cara Mudah ke Monas Naik Kendaraan Umum - Kompas.com                                                                                                                                                                                                                                                                 https://news.google.com/rss/articles/CBMipAFBVV95cUxOdmVnTV9vOTluX1hVMUcxakdjVlFtM05ham9PSUkxSmJYdW16MzNBQjVLWUJ3TVk3UDJuc3d0dkt3cVB2UWN4a1ExbXhYcWdqQ3UtT3RUWkFtV01oeWtXU2c5VVBjTU1aRFJWRXp3OFpSb3YtcUdUV2E5SXQyNjNrOWs2b2E0Z3BlMlJEdzZBRnpfbmo2UlZTdTRFb1VDY1JDZDdHUg?oc=5                                                        Kompas.com 2023-01-05 08:00:00+00:00                                                                                                                                                                                                                                                                                                    <a href="https://news.google.com/rss/articles/CBMipAFBVV95cUxOdmVnTV9vOTluX1hVMUcxakdjVlFtM05ham9PSUkxSmJYdW16MzNBQjVLWUJ3TVk3UDJuc3d0dkt3cVB2UWN4a1ExbXhYcWdqQ3UtT3RUWkFtV01oeWtXU2c5VVBjTU1aRFJWRXp3OFpSb3YtcUdUV2E5SXQyNjNrOWs2b2E0Z3BlMlJEdzZBRnpfbmo2UlZTdTRFb1VDY1JDZDdHUg?oc=5" target="_blank">4 Cara Mudah ke Monas Naik Kendaraan Umum</a>&nbsp;&nbsp;<font color="#6f6f6f">Kompas.com</font>
# 3e6c27c0510a535a Jaklingko after:2023-01-01 before:2023-02-01                                                                                       Panduan Menikmati Transportasi Umum di Jakarta - Mojok.co                                                                                                                                 https://news.google.?oc=5                                                          Mojok.co 2023-02-01 08:00:00+00:00                                                                                                                                                                 <a href="https://news.google.?oc=5" target="_blank">Panduan Menikmati Transportasi Umum di Jakarta</a>&nbsp;&nbsp;<font color="#6f6f6f">Mojok.co</font>
# 74de714aa0c54d7b Jaklingko after:2023-01-01 before:2023-02-01                                                       Bagaimana Jika Saldo di TransJakarta Kurang? Cari Tahu di Sini! - kumparan.com - Kumparan https://news.google....?oc=5                                                          Kumparan 2023-01-08 08:00:00+00:00 <a href="https://news.google....?oc=5" target="_blank">Bagaimana Jika Saldo di TransJakarta Kurang? Cari Tahu di Sini! - kumparan.com</a>&nbsp;&nbsp;<font color="#6f6f6f">Kumparan</font>
# e7ea2c0023627ca8 Jaklingko after:2023-01-01 before:2023-02-01                                                             Tak Ada Kenaikan Tarif Integrasi JakLingko, Dishub : Masih Rp 10 Ribu - IDX Channel                   https://news.google....?oc=5                                                       IDX Channel 2023-01-31 08:00:00+00:00                         <a href="https://news.google....?oc=5" target="_blank">Tak Ada Kenaikan Tarif Integrasi JakLingko, Dishub : Masih Rp 10 Ribu</a>&nbsp;&nbsp;<font color="#6f6f6f">IDX Channel</font>
# c9ae7840055fa329 Jaklingko after:2023-01-01 before:2023-02-01                                                                     2 Cara Pindah Saldo E-Money ke Rekening Bank dan E-Wallet - www.indozone.id                                                                                                                                                                                                                                                                         https://news.google.com/rss/articles/CBMingFBVV95cUxNaThPR0diRE1QcTNPNHEwbXlZVDRHaXdnZENCcUxabG1rQXhudXVCbWZnaWpSWEt5TXNpUHJJY29wY2hLRllGSXZIOXUxbHkwbTNPVG9kcEMxdDI2RDZWdDN4dkwzWEVnc3U0Y183aE9wT0tzMnZFWE5YNG0yd0pJeUhJSEY0ektlWVVuNWE3VlZpcTA2VkFyOTJ4RUdEdw?oc=5                                                   www.indozone.id 2023-01-04 08:00:00+00:00                                                                                                                                                                                                                                                                                       <a href="https://news.google.com/rss/articles/CBMingFBVV95cUxNaThPR0diRE1QcTNPNHEwbXlZVDRHaXdnZENCcUxabG1rQXhudXVCbWZnaWpSWEt5TXNpUHJJY29wY2hLRllGSXZIOXUxbHkwbTNPVG9kcEMxdDI2RDZWdDN4dkwzWEVnc3U0Y183aE9wT0tzMnZFWE5YNG0yd0pJeUhJSEY0ektlWVVuNWE3VlZpcTA2VkFyOTJ4RUdEdw?oc=5" target="_blank">2 Cara Pindah Saldo E-Money ke Rekening Bank dan E-Wallet</a>&nbsp;&nbsp;<font color="#6f6f6f">www.indozone.id</font>
# 2464f724d1573577 Jaklingko after:2023-01-01 before:2023-02-01                                                                                          Rute Transjakarta 10K Tanjung Priok-Senen - Kompas.com                                                                                                                                                                                                                                                                         https://news.google.com/rss/articles/CBMingFBVV95cUxQdmtSRjl1Ty1IMVNBNUNXYWs5UTZ1RXJEc1BCZVkyTUVVRE9MdnhNaHB3VHdCdzUyTW9oN3YwbVlFUVNhQkdsRzNzQnl2RjlpWFdYY3VLTFEtbERtZUdQSEcxazZGd2tlTGpHOG4wUjBRT2w5VE5NVE5Ha1ZMZTlVdkd2ZkdHTm5kU2NmTlZqZVFvUGJDdEMzNFN5NlRlQQ?oc=5                                                        Kompas.com 2023-01-04 08:00:00+00:00                                                                                                                                                                                                                                                                                                            <a href="https://news.google.com/rss/articles/CBMingFBVV95cUxQdmtSRjl1Ty1IMVNBNUNXYWs5UTZ1RXJEc1BCZVkyTUVVRE9MdnhNaHB3VHdCdzUyTW9oN3YwbVlFUVNhQkdsRzNzQnl2RjlpWFdYY3VLTFEtbERtZUdQSEcxazZGd2tlTGpHOG4wUjBRT2w5VE5NVE5Ha1ZMZTlVdkd2ZkdHTm5kU2NmTlZqZVFvUGJDdEMzNFN5NlRlQQ?oc=5" target="_blank">Rute Transjakarta 10K Tanjung Priok-Senen</a>&nbsp;&nbsp;<font color="#6f6f6f">Kompas.com</font>
