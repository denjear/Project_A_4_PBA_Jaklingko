# %% [markdown]
# ## Import Library & Load Dataset

# %%
# ============================================================
# 📦 IMPORT LIBRARY DAN LOAD DATASET
# ============================================================

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt

# Konfigurasi visual
plt.style.use("seaborn-v0_8-muted")

# === Load dataset utama ===
df = pd.read_csv("jaklingko_text_final.csv")

# Pastikan kolom yang dibutuhkan ada
required_cols = ['Date', 'stemmed_text', 'content_label']
for col in required_cols:
    if col not in df.columns:
        raise KeyError(f"Kolom '{col}' tidak ditemukan di dataset!")

# Ubah kolom tanggal ke format datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df = df.dropna(subset=['Date', 'stemmed_text']).reset_index(drop=True)

print(f"✅ Dataset berhasil dimuat: {len(df)} baris")
df.head(3)
# Out:
# ✅ Dataset berhasil dimuat: 154 baris
#    No                                              Title  \
# 0   1  Nasib Sopir Jaklingko, Saat Tarikan Gas tak Se...
# 1   2  Naik MRT, KRL, Transjakarta, hingga JakLingko ...
# 2   3  Dilema Hadirnya Jaklingko, Sopir Angkot Regula...
#
#                              Source       Date  \
# 0          https://www.republika.id 2025-08-06
# 1       https://nasional.kompas.com 2025-08-01
# 2  https://wartakota.tribunnews.com 2025-09-27
#
#                                                  URL  \
# 0  https://www.republika.id/posts/58688/nasib-sop...
# 1  https://nasional.kompas.com/read/2025/08/01/11...
# 2  https://wartakota.tribunnews.com/jakarta/86893...
#
#                                         article_text  \
# 0  REPUBLIKA.ID, JAKARTA — Sudah tiga bulan, Didi...
# 1  JAKARTA, KOMPAS.com - Pemerintah menetapkan di...
# 2  WARTAKOTALIVE.COM, JAKARTA -Hadirnya Jaklingko...
#
#                                         cleaned_text  \
# 0  republika id jakarta sudah tiga bulan didin bu...
# 1  jakarta kompas com pemerintah menetapkan disko...
# 2  wartakotalive com jakarta hadirnya jaklingko s...
#
#                                               tokens  \
# 0  ['republika', 'jakarta', 'didin', 'nama', 'tra...
# 1  ['jakarta', 'kompas', 'com', 'pemerintah', 'me...
# 2  ['wartakotalive', 'com', 'jakarta', 'hadirnya'...
#
#                                       stemmed_tokens  \
# 0  ['republika', 'jakarta', 'din', 'nama', 'train...
# 1  ['jakarta', 'kompas', 'com', 'pemerintah', 'te...
# 2  ['wartakotalive', 'com', 'jakarta', 'hadir', '...
#
#                                         stemmed_text sentiment content_label
# 0  republika jakarta din nama trainee sopir mikro...   negatif       opinion
# 1  jakarta kompas com pemerintah tetap diskon tar...   positif        policy
# 2  wartakotalive com jakarta hadir jaklingko angk...   negatif       opinion

# %% [markdown]
# ## Top Words TF-IDF (Time Frame)

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df = df.dropna(subset=['stemmed_text', 'Date'])

# === Tambah kolom waktu ===
df['Month'] = df['Date'].dt.to_period('M').astype(str)    # contoh: 2025-06
df['Quarter'] = df['Date'].dt.to_period('Q').astype(str)  # contoh: 2025Q2

print("Contoh hasil transformasi waktu:")
print(df[['Date', 'Month', 'Quarter']].head())

# === Fungsi bantu untuk TF-IDF ===
def compute_tfidf(corpus, max_features=1000, ngram_range=(1,2)):
    """
    Hitung TF-IDF untuk kumpulan teks dan kembalikan dataframe
    dengan rata-rata skor per kata.
    """
    vectorizer = TfidfVectorizer(max_features=max_features, ngram_range=ngram_range)
    X = vectorizer.fit_transform(corpus)
    feature_names = vectorizer.get_feature_names_out()
    tfidf_df = pd.DataFrame(X.toarray(), columns=feature_names)
    tfidf_mean = tfidf_df.mean().sort_values(ascending=False)
    result = pd.DataFrame(tfidf_mean).reset_index()
    result.columns = ['term', 'tfidf']
    return result

# === TF-IDF berdasarkan Quarter ===
quarters = df['Quarter'].unique()

for q in sorted(quarters):
    subset = df[df['Quarter'] == q]
    tfidf_q = compute_tfidf(subset['stemmed_text'].astype(str))

    print(f"\n===== 🔸 Top 10 TF-IDF Words untuk {q} =====")
    print(tfidf_q.head(10))

    # === Visualisasi ===
    plt.figure(figsize=(8,4))
    plt.barh(tfidf_q.head(10)['term'], tfidf_q.head(10)['tfidf'], color='teal')
    plt.gca().invert_yaxis()
    plt.title(f"Top 10 Words - {q}")
    plt.xlabel("TF-IDF Score")
    plt.ylabel("Word")
    plt.tight_layout()
    plt.show()
# Out:
# Contoh hasil transformasi waktu:
#         Date    Month Quarter
# 0 2025-08-06  2025-08  2025Q3
# 1 2025-08-01  2025-08  2025Q3
# 2 2025-09-27  2025-09  2025Q3
# 3 2025-08-30  2025-08  2025Q3
# 4 2025-04-10  2025-04  2025Q2
#
# ===== 🔸 Top 10 TF-IDF Words untuk 2023Q1 =====
#                   term     tfidf
# 0            jaklingko  0.157067
# 1                kartu  0.124022
# 2            indonesia  0.092759
# 3              jakarta  0.088560
# 4      kartu jaklingko  0.080773
# 5  jaklingko indonesia  0.075334
# 6             direktur  0.064673
# 7         transportasi  0.059864
# 8                 mega  0.054815
# 9                  mrt  0.052177
# ===== 🔸 Top 10 TF-IDF Words untuk 2023Q2 =====
#         term     tfidf
# 0  jaklingko  0.122812
# 1      sopir  0.097837
# 2    syafrin  0.087086
# 3      kartu  0.077391
# 4  komisaris  0.073883
# 5  penumpang  0.070321
# 6     angkat  0.063244
# 7    jakarta  0.062977
# 8      kevin  0.060612
# 9  indonesia  0.060000
# ===== 🔸 Top 10 TF-IDF Words untuk 2023Q3 =====
#            term     tfidf
# 0     jaklingko  0.144072
# 1    mikrotrans  0.122009
# 2       jakarta  0.116929
# 3  transportasi  0.082399
# 4        sistem  0.077718
# 5     integrasi  0.075749
# 6      angkutan  0.072044
# 7          nama  0.056400
# 8           dki  0.055717
# 9        angkot  0.053719
# ===== 🔸 Top 10 TF-IDF Words untuk 2023Q4 =====
#            term     tfidf
# 0     jaklingko  0.156169
# 1  transportasi  0.112596
# 2     integrasi  0.101173
# 3         tarif  0.090116
# 4       jakarta  0.086142
# 5      angkutan  0.071075
# 6  transjakarta  0.070763
# 7      terminal  0.067117
# 8       layanan  0.066261
# 9        sesuai  0.061460
# ===== 🔸 Top 10 TF-IDF Words untuk 2025Q1 =====
#            term     tfidf
# 0     jaklingko  0.113116
# 1       jakarta  0.100214
# 2  transportasi  0.069450
# 3       pramono  0.063035
# 4          laku  0.059215
# 5         sopir  0.058380
# 6        angkot  0.055972
# 7         jalan  0.055965
# 8       lebaran  0.054523
# 9           tap  0.050743
# ===== 🔸 Top 10 TF-IDF Words untuk 2025Q2 =====
#               term     tfidf
# 0          jakarta  0.108810
# 1        jaklingko  0.099890
# 2          pramono  0.066844
# 3            sopir  0.059638
# 4             kota  0.048607
# 5     transportasi  0.048453
# 6       mikrotrans  0.043180
# 7  sopir jaklingko  0.042929
# 8           celaka  0.042153
# 9           daerah  0.041399
# ===== 🔸 Top 10 TF-IDF Words untuk 2025Q3 =====
#            term     tfidf
# 0       jakarta  0.092739
# 1     jaklingko  0.062487
# 2          besi  0.058633
# 3  transjakarta  0.058488
# 4  transportasi  0.053237
# 5       layanan  0.052769
# 6          curi  0.051134
# 7           jak  0.049975
# 8        hilang  0.049515
# 9         henti  0.048704
# ===== 🔸 Top 10 TF-IDF Words untuk 2025Q4 =====
#            term     tfidf
# 0  transjakarta  0.344447
# 1     jaklingko  0.246034
# 2         tarif  0.246034
# 3      angkutan  0.196827
# 4          bank  0.196827
# 5        diskon  0.196827
# 6  diskon tarif  0.147620
# 7          laku  0.147620
# 8           lrt  0.147620
# 9           mrt  0.147620

# %% [markdown]
# ## Top Words TF-IDF (Content Label)

# %%
# ============================================================
# 🏷️ TF-IDF ANALYSIS BERDASARKAN CONTENT LABEL
# ============================================================

from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt

content_labels = df['content_label'].dropna().unique().tolist()
print(f"🔹 Ditemukan {len(content_labels)} kategori konten:", content_labels)

for label in content_labels:
    subset = df[df['content_label'] == label]
    if len(subset) < 3:
        continue  # lewati kategori dengan artikel sedikit

    tfidf_label = compute_tfidf(subset['stemmed_text'].astype(str))

    print(f"\n===== 🟦 Top 10 TF-IDF Words untuk kategori: {label.upper()} =====")
    print(tfidf_label.head(10))

    # Visualisasi
    plt.figure(figsize=(8,4))
    plt.barh(tfidf_label.head(10)['term'], tfidf_label.head(10)['tfidf'], color='darkorange')
    plt.gca().invert_yaxis()
    plt.title(f"Top 10 Words - {label.capitalize()}")
    plt.xlabel("TF-IDF Score")
    plt.ylabel("Word")
    plt.tight_layout()
    plt.show()
# Out:
# 🔹 Ditemukan 3 kategori konten: ['opinion', 'policy', 'news']
#
# ===== 🟦 Top 10 TF-IDF Words untuk kategori: OPINION =====
#            term     tfidf
# 0     jaklingko  0.098641
# 1       jakarta  0.070668
# 2         sopir  0.066369
# 3    mikrotrans  0.047954
# 4  transportasi  0.045363
# 5           jak  0.039294
# 6         kartu  0.038762
# 7        angkot  0.038010
# 8       pramono  0.037765
# 9        celaka  0.035703
# ===== 🟦 Top 10 TF-IDF Words untuk kategori: POLICY =====
#                   term     tfidf
# 0            jaklingko  0.116063
# 1              jakarta  0.110792
# 2           mikrotrans  0.070125
# 3         transportasi  0.066245
# 4            integrasi  0.055807
# 5            indonesia  0.049444
# 6               sistem  0.048228
# 7         transjakarta  0.047369
# 8             angkutan  0.045105
# 9  jaklingko indonesia  0.043405
# ===== 🟦 Top 10 TF-IDF Words untuk kategori: NEWS =====
#                term     tfidf
# 0         jaklingko  0.102309
# 1           jakarta  0.092500
# 2            angkot  0.088702
# 3            tabrak  0.074523
# 4             motor  0.064058
# 5           lebaran  0.057316
# 6      transportasi  0.054110
# 7  angkot jaklingko  0.053478
# 8           kendara  0.053398
# 9              luka  0.052719
